# %%
# !pip install pymongo
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pymongo
#   Obtaining dependency information for pymongo from https://files.pythonhosted.org/packages/02/68/b71c4106d03eef2482eade440c6f5737c2a4a42f6155726009f80ea38d06/pymongo-4.10.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading pymongo-4.10.1-cp311-cp311-win_amd64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Obtaining dependency information for dnspython<3.0.0,>=1.16.0 from https://files.pythonhosted.org/packages/68/1b/e0a87d256e40e8c888847551b20a017a6b98139178505dc7ffb96f04e954/dnspython-2.7.0-py3-none-any.whl.metadata
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.10.1-cp311-cp311-win_amd64.whl (876 kB)
#    ---------------------------------------- 0.0/876.5 kB ? eta -:--:--
#    -------------- ------------------------- 327.7/876.5 kB 6.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 634.9/876.5 kB 6.6 MB/s eta 0:00:01
#    ---------------------------------------  870.4/876.5 kB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 876.5/876.5 kB 5.0 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ---------------------------------------- 0.0/313.6 kB ? eta -:--:--
#    ------------------------------- -------- 245.8/313.6 kB 7.6 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.6 kB 9.6 MB/s eta 0:00:01
#    ---------------------------------------- 313.6/313.6 kB 3.3 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.10.1

# %%
from pymongo import MongoClient

# %%
import pandas as pd

# %%
client = MongoClient('mongodb://localhost:27017/')
db = client['mydb']
collection = db['mycollection']

# %%
df = pd.read_csv('medical.csv')

collection.insert_many(df.to_dict('records'))

print("Data inserted into MongoDB successfully.")

df_mongo = pd.DataFrame(list(collection.find()))

print("DataFrame created")
print(df_mongo.head())
# Out:
# Data inserted into MongoDB successfully.
# DataFrame created
#                         _id  provider_id  acceptsassignement  \
# 0  6718c7cd1f1b979ecaa419b1     20476193                True
# 1  6718c7cd1f1b979ecaa419b2     23279359                True
# 2  6718c7cd1f1b979ecaa419b3     23279371                True
# 3  6718c7cd1f1b979ecaa419b4     21610857                True
# 4  6718c7cd1f1b979ecaa419b5     23279377                True
#
#   participationbegindate                businessname  \
# 0             2024-02-26            CROWN PHARMA INC
# 1             2024-02-26     GM MEDICAL SUPPLIES LLC
# 2             2024-02-22  GRACE MEDICAL SERVICES LLC
# 3             2024-02-22              PARSONS RX INC
# 4             2024-02-22          ADL SOLUTIONS, INC
#
#                  practicename            practiceaddress1 practiceaddress2  \
# 0             LAVIDA PHARMACY                4020 82ND ST              NaN
# 1     GM MEDICAL SUPPLIES LLC             150 E SAMPLE RD          STE 340
# 2  GRACE MEDICAL SERVICES LLC  5598 GENERAL WASHINGTON DR         STE B005
# 3              PARSONS RX INC      159-16B UNION TURNPIKE              NaN
# 4         ADL SOLUTIONS, INC.             221 E WILLIS RD            STE 6
#
#     practicecity practicestate  practicezip9code  telephonenumber  \
# 0       ELMHURST            NY         113731305     7.184263e+09
# 1  POMPANO BEACH            FL         330643550     8.882270e+09
# 2     ALEXANDRIA            VA         223122465     5.714886e+09
# 3  FRESH MEADOWS            NY         113661954     7.183743e+09
# 4       CHANDLER            AZ         852861691     4.806362e+09
#
#                specialitieslist providertypelist  \
# 0                      Pharmacy              NaN
# 1  Medical Supply Company Other              NaN
# 2               Certified Other              NaN
# 3                      Pharmacy              NaN
# 4  Medical Supply Company Other              NaN
#
#                                         supplieslist   latitude   longitude  \
# 0  Epoetin|Immunosuppressive Drugs|Infusion Drugs...  40.747250  -73.884070
# 1  Blood Glucose Monitors/Supplies (Non-Mail Orde...  26.274737  -80.120568
# 2  Epoetin|Immunosuppressive Drugs|Infusion Drugs...  38.799573  -77.163470
# 3  Epoetin|Immunosuppressive Drugs|Infusion Drugs...  40.726438  -73.789814
# 4  Commodes, Urinals, Bedpans|Continuous Passive ...  33.283575 -111.838680
#
#    is_contracted_for_cba
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False

# %%
providers_in_ca = df[df['practicestate'] == 'CA']
print(providers_in_ca[:10])
# Out:
#     provider_id  acceptsassignement participationbegindate  \
# 10     24547980               False             2024-02-19
# 25     23279449               False             2024-02-09
# 37     23280289                True             2024-02-03
# 40     23279995                True             2024-02-01
# 49     20571881                True             2024-01-01
# 68     20646239                True             2024-01-01
# 69     20646251                True             2024-01-01
# 73     20646113                True             2024-01-01
# 74     20646107                True             2024-01-01
# 78     20614067               False             2024-01-01
#
#                                businessname  \
# 10                     BEEMANS BOUTIQUE LLC
# 25                   MAGNACARE PHARMACY LLC
# 37                         PEAQ MEDICAL LLC
# 40                             FRANCHEZ LLC
# 49                   OPTUM PHARMACY 707 INC
# 68  REGENTS OF THE UNIVERSITY OF CALIFORNIA
# 69  REGENTS OF THE UNIVERSITY OF CALIFORNIA
# 73  REGENTS OF THE UNIVERSITY OF CALIFORNIA
# 74  REGENTS OF THE UNIVERSITY OF CALIFORNIA
# 78              ADVANCED MEDICAL SUPPLY INC
#
#                            practicename           practiceaddress1  \
# 10                 BEEMANS BOUTIQUE LLC              355 E 21ST ST
# 25                   MAGNACARE PHARMACY       1235 LONG BEACH BLVD
# 37                     PEAQ MEDICAL LLC                230 GODDARD
# 40           RAPIDCARE MEDICAL SUPPLIES             1356 E 41ST ST
# 49               OPTUM PHARMACY 707 INC         4900 RIVERGRADE RD
# 68      AMBULATORY CARE CENTER PHARMACY                  4860 Y ST
# 69  REGENTS OF THE UNIVERSITY OF CALIFO    3575 BUSINESS DR # 1601
# 73  PAVILLION PHARMACY AT UC DAVIS MEDI         2315 STOCKTON BLVD
# 74              UC DAVIS MEDICAL CENTER                  4501 X ST
# 78          ADVANCED MEDICAL SUPPLY INC  1621 S RANCHO SANTA FE RD
#
#    practiceaddress2    practicecity practicestate  practicezip9code  \
# 10            STE J  SAN BERNARDINO            CA         924044851
# 25              NaN      LONG BEACH            CA             90813
# 37              NaN          IRVINE            CA         926184625
# 40            STE B     LOS ANGELES            CA         900113302
# 49         STE E110       IRWINDALE            CA         917061460
# 68              NaN      SACRAMENTO            CA         958172307
# 69              NaN      SACRAMENTO            CA         958202160
# 73         RM 1P175      SACRAMENTO            CA         958172229
# 74          RM 1008      SACRAMENTO            CA         958172229
# 78            STE H      SAN MARCOS            CA         920782125
#
#     telephonenumber              specialitieslist providertypelist  \
# 10     9.098820e+09          Prosthetic Personnel              NaN
# 25     5.624360e+09                      Pharmacy              NaN
# 37     9.498509e+09  Medical Supply Company Other              NaN
# 40     2.138142e+09  Medical Supply Company Other              NaN
# 49     3.232275e+09                      Pharmacy              NaN
# 68     9.167346e+09                      Pharmacy              NaN
# 69     9.167035e+09                      Pharmacy              NaN
# 73     9.167036e+09                      Pharmacy              NaN
# 74     9.167346e+09                      Pharmacy              NaN
# 78     7.605108e+09  Medical Supply Company Other              NaN
#
#                                          supplieslist   latitude   longitude  \
# 10               Breast Prostheses and/or Accessories  34.133442 -117.277950
# 25  Epoetin|Immunosuppressive Drugs|Nebulizer Drug...  33.782199 -118.189851
# 37       Blood Glucose Monitors/Supplies (Mail Order)  33.631793 -117.742398
# 40  Commodes, Urinals, Bedpans|Blood Glucose Monit...  34.008748 -118.250187
# 49  Epoetin|Immunosuppressive Drugs|Infusion Drugs...  34.102510 -117.979550
# 68  Epoetin|Immunosuppressive Drugs|Nebulizer Drug...  38.552570 -121.448990
# 69  Infusion Drugs|Blood Glucose Monitors/Supplies...  38.837600 -121.294810
# 73  Epoetin|Immunosuppressive Drugs|Nebulizer Drug...  38.553640 -121.456670
# 74  Epoetin|Immunosuppressive Drugs|Nebulizer Drug...  38.553560 -121.452890
# 78  Commodes, Urinals, Bedpans|Hospital Beds (Elec...  33.118570 -117.223180
#
#     is_contracted_for_cba
# 10                  False
# 25                  False
# 37                  False
# 40                  False
# 49                  False
# 68                  False
# 69                  False
# 73                  False
# 74                  False
# 78                  False

# %%
ny_providers = df[(df['practicestate'] == 'NY') & (df['specialitieslist'] == 'Medical Supply Company Other') & (df['supplieslist'] == 'OXYGEN & EQUIPMENT')]
print(ny_providers)
# Out:
# Empty DataFrame
# Columns: [provider_id, acceptsassignement, participationbegindate, businessname, practicename, practiceaddress1, practiceaddress2, practicecity, practicestate, practicezip9code, telephonenumber, specialitieslist, providertypelist, supplieslist, latitude, longitude, is_contracted_for_cba]
# Index: []

# %%
for row in df.iterrows():
    if row[0] == '20506619':
        row[10] = '123123123'
        print(row)

# %%
supplylist = df.groupby(df['supplieslist'])
print(list(supplylist)[:10])
# Out:
# [('(TENS) Transcutaneous Electrical Nerve Stimulators and/or Supplies|Canes and/or Crutches|Cochlear Implants',        provider_id  acceptsassignement participationbegindate  \
# 54305     20672141                True             1993-01-01
#
#                   businessname          practicename  \
# 54305  SUMMIT MEDICAL GROUP PA  SUMMIT MEDICAL GROUP
#
#                            practiceaddress1 practiceaddress2  \
# 54305  1 DIAMOND HILL RD, BENSLEY PAVILLION              NaN
#
#            practicecity practicestate  practicezip9code telephonenumber  \
# 54305  BERKELEY HEIGHTS            NJ          79222101       123123123
#
#       specialitieslist            providertypelist  \
# 54305              NaN  AMBULATORY SURGICAL CENTER
#
#                                             supplieslist  latitude  longitude  \
# 54305  (TENS) Transcutaneous Electrical Nerve Stimula...   40.6778  -74.40949
#
#        is_contracted_for_cba
# 54305                  False  ), ('(TENS) Transcutaneous Electrical Nerve Stimulators and/or Supplies|Canes and/or Crutches|Orthoses: Custom Fabricated|Diabetic Shoes and Inserts|Diabetic Shoes/Inserts - Custom',        provider_id  acceptsassignement participationbegindate  \
# 44679     20607869                True             2002-01-01
#
#                        businessname                         practicename  \
# 44679  INNOVATIVE FOOT AND ANKLE PA  DANIEL BRANDWEIN DPM AND SEAN KAUFM
#
#       practiceaddress1 practiceaddress2 practicecity practicestate  \
# 44679    528 BOULEVARD              NaN   KENILWORTH            NJ
#
#        practicezip9code telephonenumber  \
# 44679          70331657       123123123
#
#                               specialitieslist      providertypelist  \
# 44679  Orthotic Personnel|Prosthetic Personnel  PHYSICIAN – PODIATRY
#
#                                             supplieslist  latitude  longitude  \
# 44679  (TENS) Transcutaneous Electrical Nerve Stimula...   40.6762  -74.29091
#
#        is_contracted_for_cba
# 44679                  False  ), ('(TENS) Transcutaneous Electrical Nerve Stimulators and/or Supplies|Canes and/or Crutches|Orthoses: Custom Fabricated|Orthoses: Prefabricated (Non-Custom Fabricated)|Orthoses: Off-The-Shelf|Diabetic Shoes and Inserts|Diabetic Shoes/Inserts - Custom',        provider_id  acceptsassignement participationbegindate  businessname  \
# 22879     26716102                True             1998-01-01  SALEM HEALTH
#
#        practicename practiceaddress1 practiceaddress2 practicecity  \
# 22879  STATE STREET    1600 STATE ST              NaN        SALEM
#
#       practicestate  practicezip9code telephonenumber      specialitieslist  \
# 22879            OR         973014257       123123123  Prosthetic Personnel
#
#                                 providertypelist  \
# 22879  PHYSICIAN – ORTHOPEDIC/ORTHOPEDIC SURGERY
#
#                                             supplieslist   latitude  \
# 22879  (TENS) Transcutaneous Electrical Nerve Stimula...  44.934798
#
#         longitude  is_contracted_for_cba
# 22879 -123.021486                  False  ), ('(TENS) Transcutaneous Electrical Nerve Stimulators and/or Supplies|Canes and/or Crutches|Patient Lifts|Power Operated Vehicles (Scooters)|Walkers|Orthoses: Off-The-Shelf|Penile Pumps|Diabetic Shoes and Inserts|Diabetic Shoes/Inserts - Custom',        provider_id  acceptsassignement participationbegindate  \
# 51082     20682785               False             2002-01-28
#
#                        businessname                  practicename  \
# 51082  PAIN MANAGEMENT TECHNOLOGIES  PAIN MANAGEMENT TECHNOLOGIES
#
#         practiceaddress1 practiceaddress2 practicecity practicestate  \
# 51082  1760 WADSWORTH RD              NaN        AKRON            OH
#
#        practicezip9code telephonenumber              specialitieslist  \
# 51082             44320       123123123  Medical Supply Company Other
#
#       providertypelist                                       supplieslist  \
# 51082              NaN  (TENS) Transcutaneous Electrical Nerve Stimula...
#
#         latitude  longitude  is_contracted_for_cba
# 51082  41.056106 -81.591132                  False  ), ('(TENS) Transcutaneous Electrical Nerve Stimulators and/or Supplies|Canes and/or Crutches|Walkers|Nebulizer Equipment and/or Supplies|Lymphedema Compression Treatment Items',        provider_id  acceptsassignement participationbegindate  \
# 59661     20605097               False             2002-07-01
#
#                              businessname                        practicename  \
# 59661  PARK NICOLLET HEALTH CARE PRODUCTS  PARK NICOLLET HEALTH CARE PRODUCTS
#
#       practiceaddress1 practiceaddress2 practicecity practicestate  \
# 59661  537 PHALEN BLVD          STE 101   SAINT PAUL            MN
#
#        practicezip9code telephonenumber              specialitieslist  \
# 59661         551305303       123123123  Medical Supply Company Other
#
#       providertypelist                                       supplieslist  \
# 59661              NaN  (TENS) Transcutaneous Electrical Nerve Stimula...
#
#        latitude  longitude  is_contracted_for_cba
# 59661  44.96549  -93.07686                  False  ), ('(TENS) Transcutaneous Electrical Nerve Stimulators and/or Supplies|Canes and/or Crutches|Walkers|Orthoses: Custom Fabricated|Orthoses: Prefabricated (Non-Custom Fabricated)|Orthoses: Off-The-Shelf|Breast Prostheses and/or Accessories|Limb Prostheses|Diabetic Shoes and Inserts|Diabetic Shoes/Inserts - Custom|Lymphedema Compression Treatment Items',        provider_id  acceptsassignement participationbegindate  \
# 58537     20653409               False             1998-01-01
#
#                                     businessname    practicename  \
# 58537  BODY IN MOTION SPORTS & ORTHOPAEDICS, INC  BODY IN MOTION
#
#        practiceaddress1 practiceaddress2 practicecity practicestate  \
# 58537  437 LAKEHURST RD              NaN   TOMS RIVER            NJ
#
#        practicezip9code telephonenumber  \
# 58537          87557378       123123123
#
#                                         specialitieslist providertypelist  \
# 58537  MSC With Orthotic Personnel|Orthotic Personnel...              NaN
#
#                                             supplieslist  latitude  longitude  \
# 58537  (TENS) Transcutaneous Electrical Nerve Stimula...  39.96042  -74.21721
#
#        is_contracted_for_cba
# 58537                  False  ), ('(TENS) Transcutaneous Electrical Nerve Stimulators and/or Supplies|Canes and/or Crutches|Walkers|Orthoses: Custom Fabricated|Orthoses: Prefabricated (Non-Custom Fabricated)|Orthoses: Off-The-Shelf|Breast Prostheses and/or Accessories|Nebulizer Equipment and/or Supplies|Diabetic Shoes and Inserts',        provider_id  acceptsassignement participationbegindate  \
# 30948     20646707                True             1998-01-01
# 45987     20546219                True             2010-01-27
#
#              businessname        practicename practiceaddress1  \
# 30948    MAIN SURGICAL CO    MAIN SURGICAL CO      84 BROADWAY
# 45987  MIKHAEL RUZHIN LTD  MIKHAEL RUZHIN LTD   26-17 BROADWAY
#
#              practiceaddress2 practicecity practicestate  practicezip9code  \
# 30948  VALUE MEDICAL SUPPLIES       NEWARK            NJ          71042504
# 45987                     NaN    FAIR LAWN            NJ          74103821
#
#       telephonenumber                                   specialitieslist  \
# 30948       123123123  Medical Supply Company Other|MSC With Orthotic...
# 45987       123123123                       MSC With Orthotic-Prosthetic
#
#           providertypelist                                       supplieslist  \
# 30948  PEDORTHIC PERSONNEL  (TENS) Transcutaneous Electrical Nerve Stimula...
# 45987  PEDORTHIC PERSONNEL  (TENS) Transcutaneous Electrical Nerve Stimula...
#
#        latitude  longitude  is_contracted_for_cba
# 30948  40.75266  -74.17075                  False
# 45987  40.92340  -74.10934                  False  ), ('(TENS) Transcutaneous Electrical Nerve Stimulators and/or Supplies|Canes and/or Crutches|Walkers|Orthoses: Custom Fabricated|Orthoses: Prefabricated (Non-Custom Fabricated)|Orthoses: Off-The-Shelf|Breast Prostheses and/or Accessories|Nebulizer Equipment and/or Supplies|Diabetic Shoes and Inserts|Diabetic Shoes/Inserts - Custom',        provider_id  acceptsassignement participationbegindate  \
# 30913     20646761                True             1998-01-01
#
#                     businessname               practicename practiceaddress1  \
# 30913  BENEFICIAL MEDICAL SUPPLY  BENEFICIAL MEDICAL SUPPLY   361 PASSAIC ST
#
#       practiceaddress2 practicecity practicestate  practicezip9code  \
# 30913              NaN      PASSAIC            NJ          70555818
#
#       telephonenumber                                   specialitieslist  \
# 30913       123123123  MSC With Orthotic-Prosthetic|Orthotic Personne...
#
#           providertypelist                                       supplieslist  \
# 30913  PEDORTHIC PERSONNEL  (TENS) Transcutaneous Electrical Nerve Stimula...
#
#        latitude  longitude  is_contracted_for_cba
# 30913  40.86002  -74.12426                  False  ), ('(TENS) Transcutaneous Electrical Nerve Stimulators and/or Supplies|Canes and/or Crutches|Walkers|Orthoses: Custom Fabricated|Orthoses: Prefabricated (Non-Custom Fabricated)|Orthoses: Off-The-Shelf|Limb Prostheses|Diabetic Shoes and Inserts|Diabetic Shoes/Inserts - Custom|Lymphedema Compression Treatment Items',        provider_id  acceptsassignement participationbegindate  \
# 35815     20653481               False             1998-01-01
#
#                                         businessname  \
# 35815  NEW ENGLAND ORTHOTIC & PROSTHETIC SYSTEMS LLC
#
#                               practicename practiceaddress1 practiceaddress2  \
# 35815  NEW ENGLAND ORTHOTIC & PROSTHETIC S   113 SALEM TPKE              NaN
#
#       practicecity practicestate  practicezip9code telephonenumber  \
# 35815      NORWICH            CT          63606484       123123123
#
#                    specialitieslist providertypelist  \
# 35815  MSC With Orthotic-Prosthetic              NaN
#
#                                             supplieslist  latitude  longitude  \
# 35815  (TENS) Transcutaneous Electrical Nerve Stimula...  41.51191  -72.11194
#
#        is_contracted_for_cba
# 35815                  False  ), ('(TENS) Transcutaneous Electrical Nerve Stimulators and/or Supplies|Canes and/or Crutches|Walkers|Orthoses: Prefabricated (Non-Custom Fabricated)|Orthoses: Off-The-Shelf',        provider_id  acceptsassignement participationbegindate  \
# 7116      20411945                True             2020-09-17
# 26996     20587355                True             2004-08-01
# 50771     20586257                True             2004-12-15
#
#                          businessname                      practicename  \
# 7116   CENTRAL FLORIDA SPINE AND PAIN  CENTRAL FLORIDA SPINE & PAIN LLC
# 26996       SPECIALTY ORTHOPAEDICS PC      SPECIALTY ORTHOPAEDICS, P.C.
# 50771   STRATUS ORTHOPEDIC SUPPLY INC     STRATUS ORTHOPEDIC SUPPLY INC
#
#                 practiceaddress1 practiceaddress2 practicecity practicestate  \
# 7116            395 S WICKHAM RD              NaN    MELBOURNE            FL
# 26996  1240 JESSE JEWELL PKWY SE          STE 300  GAINESVILLE            GA
# 50771              3021 LORNA RD          STE 302   BIRMINGHAM            AL
#
#        practicezip9code telephonenumber  \
# 7116          329041135       123123123
# 26996         305013861       123123123
# 50771         352164500       123123123
#
#                                       specialitieslist  \
# 7116                       MSC With Orthotic Personnel
# 26996                                              NaN
# 50771  Medical Supply Company Other|Orthotic Personnel
#
#                                         providertypelist  \
# 7116                                                 NaN
# 26996  AMBULATORY SURGICAL CENTER|PHYSICIAN – GENERAL...
# 50771                                                NaN
#
#                                             supplieslist  latitude  longitude  \
# 7116   (TENS) Transcutaneous Electrical Nerve Stimula...  28.10163  -80.67253
# 26996  (TENS) Transcutaneous Electrical Nerve Stimula...  34.30384  -83.81195
# 50771  (TENS) Transcutaneous Electrical Nerve Stimula...  33.40647  -86.80462
#
#        is_contracted_for_cba
# 7116                   False
# 26996                  False
# 50771                  False  )]
